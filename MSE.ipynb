# %% [markdown]
# __Линейная регрессия. MSE__

# %% [markdown]
# $$a(x) = w_{0}+\sum^{d}_{i=1}w_{i}x_{i}.$$

# %% [markdown]
# $$a(x) = \sum^{d+1}_{i=1}w_{i}x_{i}=\left \langle w,x \right \rangle.$$

# %% [markdown]
# среднee абсолютное отклонением (mean absolute error, MAE):
#
# $$Q(a,x) = \frac{1}{l}\sum^{l}_{i=1}|a(x_{i})-y_{i}|.$$

# %% [markdown]
# _среднеквадратичное отклонение_ (mean squared error, MSE):
#
# $$Q(a,x) = \frac{1}{l}\sum^{l}_{i=1}(a(x_{i})-y_{i})^{2}.$$

# %% [markdown]
# __Метод наименьших квадратов__
# $$Q(w, X) = \frac{1}{l}||Xw-y||^{2}\rightarrow \underset{w}{\text{min}},$$
#
# где используется евклидова ($L_{2}$) норма:
#
# $$||x|| = \sqrt{\sum_{i=1}^l{x_i^2}} $$
#
# $$||Xw-y|| = \sqrt{\sum_{i=1}^l{(X_iw-y_i)^2}} $$
# $$Q(w, X) = \frac{1}{l}\sqrt{\sum_{i=1}^l{(X_iw-y_i)^2}} ^{2} = \frac{1}{l}\sum_{i=1}^l{(X_iw-y_i)^2}$$
# $\nabla_{w}Q(w,X) = \frac{2}{l}X^{T}(Xw-y).$
#
# $\frac{2}{l}X^{T}(Xw-y) = 0$
#
# $X^{T}(Xw-y) = 0$
#
# $X^{T}Xw-X^{T}y = 0$
#
# $w = \frac{X^{T}y}{X^{T}X}$
#
# $w = (X^{T}X)^{-1}X^{T}y $

# %% [markdown]
# __Градиентный спуск__
# $$ \nabla f(x_{1},...,x_{d}) = \left(\frac{\partial f}{\partial x_{i}}\right)^{d}_{i=1}.$$
# $$w^{k} = w^{k-1} - \eta_{k}\nabla Q(w^{k-1}, X).$$
# $$||w^{k}-w^{k-1}|| < \varepsilon.$$
# $$Q(w, X) = \frac{1}{l}||Xw-y||^{2}\rightarrow \underset{w}{\text{min}}$$
# $$\nabla_{w}Q(w,X) = \frac{2}{l}X^{T}(Xw-y).$$

# %% [markdown]
# 1. Инициализация w
#
# 2. Цикл по k = 1,2,3,...:
#
#     * $w^{k} = w^{k-1} - \eta_{k}\nabla Q(w^{k-1}, X)$
#
#     * Если $||w^{k} - w^{k-1}|| < \epsilon$, то завершить.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D
from sklearn import datasets

# %%
np.random.seed(1234)
# Возьмем 2 признака и 1000 объектов
n_features = 2
n_objects = 1000

# сгенерируем вектор истинных весов
w_true = np.random.normal(size=(n_features))

# сгенерируем матрицу X, вычислим Y с добавлением случайного шума
X = np.random.uniform(-7, 7, (n_objects, n_features))
Y = X.dot(w_true) + np.random.normal(0, 0.5, size=(n_objects))

# возьмем нулевые начальные веса
w = np.zeros(n_features)

# %%
display(w, w_true, X, Y)
# Out:
# array([0., 0.])
# array([ 0.47143516, -1.19097569])
# array([[-0.87181165,  3.99502017],
#        [ 3.91966131, -3.18370353],
#        [-3.12950043,  4.22621049],
#        ...,
#        [ 3.51597757,  5.11940305],
#        [ 6.35903104,  5.31390661],
#        [ 5.12347492,  2.96879971]])
# array([-5.71937308e+00,  6.42200487e+00, -6.22754907e+00, -3.61309248e+00,
#        -1.24952278e+00, -2.10667534e+00, -1.87408546e+00,  8.06711862e+00,
#        -4.75602542e+00, -2.03931948e+00, -5.77773483e-01,  8.32648436e-01,
#        -5.55413438e+00, -1.84424278e+00,  3.29500371e+00,  8.02004094e+00,
#        -1.64093596e+00, -8.35192303e+00, -6.93743921e+00,  2.59477266e+00,
#        -5.89712012e+00,  1.15446630e-01, -4.28621134e+00, -1.65799764e+00,
#        -4.20035318e+00,  8.65844888e+00, -5.58161780e+00, -5.24268607e+00,
#        -1.93540562e+00, -4.29251150e+00,  6.18523295e+00,  6.04222590e+00,
#        -8.96774218e+00,  3.69668619e+00,  3.48567877e-01,  6.04312911e+00,
# ...

# %%
import MSE as mc

# %%
my_mse = mc.MSE(X,Y)

# %%
my_mse.show_data_w0_w1_y()

# %%
my_mse.max_iter
# Out:
# 10000.0

# %%
my_mse.gradient_descent()
# Out:
# array([ 0.46622324, -1.18317885])

# %%
my_mse.show_errors_data()
# Out:
# Iter 0: error - 3.044923692126554, weights: [-0.03510077 -0.82561501]
# В случае использования градиентного спуска функционал ошибки составляет 0.2413

# %%
my_mse.show_errors()

# %%
my_mse.show_weight_ch()

# %%
my_mse.gradient_descent(100)
# Out:
# array([ 0.46828846, -1.18237649])

# %%
my_mse.show_errors_data()
# Out:
# Iter 0: error - 8.94345026291753, weights: [-0.30915952 -0.25215661]
# Iter 100: error - 0.24141764352984166, weights: [ 0.4644478  -1.17898644]
# Iter 200: error - 0.2415210501982321, weights: [ 0.47088928 -1.18629704]
# Iter 300: error - 0.24198912595848607, weights: [ 0.47305044 -1.18384593]
# Iter 400: error - 0.24147533410717495, weights: [ 0.46420256 -1.18295443]
# Iter 500: error - 0.24151649680092932, weights: [ 0.46647061 -1.17990041]
# Iter 600: error - 0.24155314320584295, weights: [ 0.46413742 -1.18205558]
# Iter 700: error - 0.2415045810257692, weights: [ 0.47362814 -1.17814163]
# Iter 800: error - 0.24377798217974478, weights: [ 0.47649795 -1.18153471]
# Iter 900: error - 0.2424611781597742, weights: [ 0.46239241 -1.19185831]
# Iter 1000: error - 0.2435389768934061, weights: [ 0.47271695 -1.18699576]
# Iter 1100: error - 0.24300454545907696, weights: [ 0.46476157 -1.17962764]
# Iter 1200: error - 0.24292798400407684, weights: [ 0.46163275 -1.18096375]
# ...

# %%
my_mse.show_errors()

# %%
my_mse.show_weight_ch()

# %%
my_mse.get_coef_cor_Pirson(1)
# Out:
# (-0.9209798704307436, 'Сильная обратная корреляционная связь.')

# %%
my_mse.get_median(-1)
# Out:
# -0.19976616012354256

# %%
my_mse.show_fig_QQ(-1)
# Out:
# C:\Users\user\Desktop\MSE\MSE.py:342: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
my_mse.shpw_hist(-1)

# %%
my_mse.get_shapiro(-1)
# Out:
# ShapiroResult(statistic=0.9810245037078857, pvalue=3.9485495428870365e-10)

# %%
my_mse.get_kstest(-1)
# Out:
# KstestResult(statistic=0.3612884516995811, pvalue=2.0044380165453374e-117, statistic_location=-1.6379932752748565, statistic_sign=1)

# %%
data_norm = my_mse.data.copy()
data_norm = data_norm.astype(np.float64)
data_norm[:,1] = my_mse.min_max_scale(1)
data_norm
# Out:
# array([[-0.87181165,  0.78558513],
#        [ 3.91966131,  0.27252278],
#        [-3.12950043,  0.80210827],
#        ...,
#        [ 3.51597757,  0.86594461],
#        [ 6.35903104,  0.87984576],
#        [ 5.12347492,  0.7122413 ]])

# %%
my_mse.data
# Out:
# array([[-0.87181165,  3.99502017],
#        [ 3.91966131, -3.18370353],
#        [-3.12950043,  4.22621049],
#        ...,
#        [ 3.51597757,  5.11940305],
#        [ 6.35903104,  5.31390661],
#        [ 5.12347492,  2.96879971]])

# %%
data_stand = my_mse.data.copy()
data_stand = data_norm.astype(np.float64)
data_stand[:,1] = my_mse.standard_scale(1)
data_stand
# Out:
# array([[-0.87181165,  0.97968864],
#        [ 3.91966131, -0.76785281],
#        [-3.12950043,  1.03596809],
#        ...,
#        [ 3.51597757,  1.25340104],
#        [ 6.35903104,  1.30074971],
#        [ 5.12347492,  0.72987225]])

# %%
np.mean(data_stand[:,1])
# Out:
# -4.263256414560601e-17

# %%
np.std(data_stand[:,1])
# Out:
# 0.9999999999999999

# %%
np.mean(data_norm[:,1])
# Out:
# 0.4979574147700093

# %%
np.std(data_norm[:,1])
# Out:
# 0.2935909491888446

# %%
my_mse.shpw_hist(-1)

# %%
my_mse.data
# Out:
# array([[-0.87181165,  3.99502017],
#        [ 3.91966131, -3.18370353],
#        [-3.12950043,  4.22621049],
#        ...,
#        [ 3.51597757,  5.11940305],
#        [ 6.35903104,  5.31390661],
#        [ 5.12347492,  2.96879971]])

# %%
X_log = my_mse.get_log_data(1)
X_log
# Out:
# C:\Users\user\Desktop\MSE\MSE.py:384: RuntimeWarning: invalid value encountered in log
#   X[:, index + 1] = np.log(X[:, index + 1])
# array([[-5.71937308, -0.87181165,  1.38504863],
#        [ 6.42200487,  3.91966131,         nan],
#        [-6.22754907, -3.12950043,  1.44130573],
#        ...,
#        [-3.97003689,  3.51597757,  1.63303784],
#        [-3.19013886,  6.35903104,  1.67032727],
#        [-0.53930057,  5.12347492,  1.08815773]])

# %%
X_sqrt = my_mse.get_sqrt_data(1)
X_sqrt
# Out:
# C:\Users\user\Desktop\MSE\MSE.py:394: RuntimeWarning: invalid value encountered in sqrt
#   X[:, index + 1] = np.sqrt(X[:, index + 1])
# array([[-5.71937308, -0.87181165,  1.99875466],
#        [ 6.42200487,  3.91966131,         nan],
#        [-6.22754907, -3.12950043,  2.05577491],
#        ...,
#        [-3.97003689,  3.51597757,  2.26260979],
#        [-3.19013886,  6.35903104,  2.30519123],
#        [-0.53930057,  5.12347492,  1.72302052]])

# %%
X_cbrt = my_mse.get_cbrt_data(1)
Y_cbrt = my_mse.get_cbrt_data(-1)
X_cbrt[:,1:], Y_cbrt[:, 0]
# Out:
# (array([[-0.87181165,  1.58674203],
#         [ 3.91966131, -1.47110681],
#         [-3.12950043,  1.61677794],
#         ...,
#         [ 3.51597757,  1.72348077],
#         [ 6.35903104,  1.745037  ],
#         [ 5.12347492,  1.43723229]]),
#  array([-1.78833747,  1.85876096, -1.8398075 , -1.53447456, -1.07708024,
#         -1.2819346 , -1.23290552,  2.00557765, -1.68169819, -1.2681241 ,
#         -0.83288659,  0.94077815, -1.77094658, -1.22632627,  1.48805381,
#          2.00166869, -1.17949801, -2.0289071 , -1.90721534,  1.37414672,
#         -1.80667482,  0.48692315, -1.62439332, -1.18357187, -1.61347387,
#          2.05343061, -1.77386282, -1.73720586, -1.24620838, -1.62518881,
#          1.83563087,  1.82137339, -2.0775957 ,  1.54621849,  0.70376736,
#          1.82146414, -1.96391811, -1.05971312,  0.95939059, -1.36771339,
#          0.51758259,  1.94213044, -1.68335758,  1.29799959, -1.39714715,
#         -1.88330978, -1.07564498, -1.65911768, -1.7474517 , -1.26505461,
# ...

# %%
my_mse = mc.MSE(X_cbrt[:,1:],Y_cbrt[:, 0])
my_mse.gradient_descent()
# Out:
# array([ 0.11181278, -0.97957677])

# %%
my_mse.shpw_hist(1)

# %%
my_mse = mc.MSE(X,Y)
my_mse.gradient_descent()
# Out:
# array([ 0.46622324, -1.18317885])

# %%
my_mse.shpw_hist(1)

# %%
X, Y, coef = datasets.make_regression(n_samples=1000, n_features=2, n_informative=2, n_targets=1, 
                                      noise=5, coef=True, random_state=21)
X[:, 0] *= 10
display(X, Y, coef)
# Out:
# array([[ 9.27509286, -0.24833515],
#        [ 5.59136909,  0.28326193],
#        [-0.7649766 ,  0.50844526],
#        ...,
#        [ 7.26956008,  0.44571863],
#        [ 0.62868788,  0.47310442],
#        [ 7.20098684, -1.98855356]])
# array([ 4.07457086e+01,  5.27244851e+01,  1.84762014e+01, -3.10380488e+01,
#         4.70671430e+01,  7.22283816e-01, -5.31759505e+01,  1.79291892e+01,
#        -6.11197697e+00,  4.05336953e+01,  2.65901972e+01,  4.84966592e+01,
#         1.55774095e+02,  5.85108997e+01,  6.46767644e+01, -7.70722849e+00,
#        -6.39016541e+01,  8.23003844e+01,  7.91263193e+01,  1.55040499e+01,
#        -2.80962580e+01, -5.49193018e+01, -1.03239071e+01,  4.41317244e+01,
#         1.99393753e+01, -9.50628412e+01, -8.73233453e+00,  5.08712512e+01,
#         9.73353987e+01, -1.30033035e+02, -4.67189433e+01,  1.35018831e+01,
#         2.19630638e+01,  7.06689060e+01, -9.32436798e+00, -1.57993251e+02,
# ...

# %%
my_mse = mc.MSE(X, Y)
my_mse.show_data_w0_w1_y()

# %%
means = np.mean(X, axis=0)
stds = np.std(X, axis=0)
# параметр axis указывается для вычисления значений по столбцам, а не по всему массиву
display(means, stds)
# Out:
# array([-0.10182512, -0.02284267])
# array([10.19621056,  0.96650558])

# %%
my_mse.set_standard_scale()
my_mse.show_data_w0_w1_y()

# %%
my_mse.gradient_descent(1)
my_mse.show_weight_ch()

# %%
my_mse.show_errors_data()
# Out:
# Iter 0: error - 5306.317695098188, weights: [0.19326877 0.04384877]
# Iter 100: error - 97.35718630073126, weights: [50.69552894 41.26288127]
# Iter 200: error - 27.706724139022693, weights: [57.9511623  41.67108374]
# Iter 300: error - 27.63815944475188, weights: [58.49496592 42.95450411]
# Iter 400: error - 26.606643344932305, weights: [59.33525558 42.09404726]
# Iter 500: error - 27.962006644738914, weights: [58.75614966 40.95432986]
# Iter 600: error - 26.894287219537755, weights: [58.53935922 41.93413492]
# Iter 700: error - 26.749933321077176, weights: [59.21008757 41.54710207]
# Iter 800: error - 27.18567963459, weights: [59.3065424  42.39467236]
# Iter 900: error - 27.18164977074669, weights: [59.26647293 41.33145016]
# Iter 1000: error - 26.601228713856354, weights: [59.25046529 42.03902831]
# Iter 1100: error - 28.27062695442424, weights: [59.41651512 43.32805805]
# Iter 1200: error - 26.67994025727211, weights: [59.13078586 41.76797168]
# ...

# %%
coef
# Out:
# array([57.87754979, 43.43399566])

# %%
my_mse.w
# Out:
# array([59.33083817, 41.99838904])

# %%
X = np.array([[ 1,  1],
              [ 1,  1],
              [ 1,  2],
              [ 1,  5],
              [ 1,  3],
              [ 1,  0],
              [ 1,  5],
              [ 1, 10],
              [ 1,  1],
              [ 1,  2]])

Y = np.array([45, 55, 50, 55, 60, 35, 75, 80, 50, 60])
Y
# Out:
# array([45, 55, 50, 55, 60, 35, 75, 80, 50, 60])

# %%
my_mse = mc.MSE(X, Y)

# %%
from sklearn.linear_model import Ridge

n = 50

train_amount = 5
train_X = X[:train_amount]
train_y = Y[:train_amount]
test_X = X[train_amount:]
test_y = Y[train_amount:]
mse_train = []
mse_test = []

# %%
X,Y
# Out:
# (array([[ 1,  1],
#         [ 1,  1],
#         [ 1,  2],
#         [ 1,  5],
#         [ 1,  3],
#         [ 1,  0],
#         [ 1,  5],
#         [ 1, 10],
#         [ 1,  1],
#         [ 1,  2]]),
#  array([45, 55, 50, 55, 60, 35, 75, 80, 50, 60]))

# %%
import MSE as mc
my_mse = mc.MSE(X,Y)
my_mse.gradient_descent()
# Out:
# array([45.06249894,  3.81250019])

# %%
my_mse.gradient_descent(0, .01, True, False, 1e-2)
# Out:
# array([44.59596743,  3.89368408])

# %%
my_mse.gradient_descent(0, .01, False, True, 1e-2)
# Out:
# array([45.05374894,  3.81375019])

# %%
my_mse.gradient_descent(0, .01, True, True, 1e-2)
# Out:
# array([44.58731172,  3.89491708])

# %%
my_mse.gradient_descent(1, .001,False, True, 1e-2)
# Out:
# array([44.75009855,  3.62964848])

# %%
my_mse.gradient_descent(1, .001, True, False, 1e-2)
# Out:
# array([44.80936858,  4.04948796])

# %%
my_mse.gradient_descent(1, .001, False, False, 1e-2)
# Out:
# array([45.02365757,  3.92217211])

# %%
my_mse.gradient_descent(1, .001, True, True, 1e-2)
# Out:
# array([44.45704818,  4.21707004])

# %%
my_mse.test_train()
# Out:
# (array([[ 1,  0],
#         [ 1,  1],
#         [ 1, 10],
#         [ 1,  1],
#         [ 1,  3],
#         [ 1,  2],
#         [ 1,  5]]),
#  array([[1, 2],
#         [1, 1],
#         [1, 5]]),
#  array([35, 50, 80, 45, 60, 60, 55]),
#  array([50, 55, 75]))

# %%
my_mse.alpha(.7, 50, True, .01)

# %%
my_mse.alpha(.7, 50, False, .01)
